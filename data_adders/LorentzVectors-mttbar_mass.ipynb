# %%
import uproot
import matplotlib
import ipykernel
import numpy as np
import scipy
import torch
import pandas as pd
import sklearn
import uproot as uproot
import root_pandas
# Out:
# Welcome to JupyROOT 6.22/06

# %%
depo_dir = '/depot/cms/top/mcnama20/TopSpinCorr-Run2-Entanglement/CMSSW_10_2_22/src/TopAnalysis/Configuration/analysis/diLeptonic/spinCorrInput_wbosons_masses_all/Nominal'
channel = "/ee"  # can also be "/ee", /emu" and "/mumu"

file = channel + "_ttbarsignalplustau_fromDilepton_TuneCP5.root"

key = "ttBar_treeVariables_step8;21"  #can also be "ttBar_treeVariables_step8;21", "ttBar_treeVariables_step8;88" and "ttBar_treeVariables_step8;40"

# %%
data = uproot.open(depo_dir + channel + file, key = key)

# %%
data.keys()
# Out:
# ['ttBar_treeVariables_step0;95',
#  'ttBar_treeVariables_step0;94',
#  'ttBar_treeVariables_step1;73',
#  'ttBar_treeVariables_step1;72',
#  'ttBar_treeVariables_step3;43',
#  'ttBar_treeVariables_step3;42',
#  'ttBar_treeVariables_step4;34',
#  'ttBar_treeVariables_step4;33',
#  'ttBar_treeVariables_step5;29',
#  'ttBar_treeVariables_step5;28',
#  'ttBar_treeVariables_step6;24',
#  'ttBar_treeVariables_step6;23',
#  'ttBar_treeVariables_step7;23',
#  'ttBar_treeVariables_step7;22',
#  'ttBar_treeVariables_step2;22',
#  'ttBar_treeVariables_step2;21',
#  'ttBar_treeVariables_step8;21',
#  'ttBar_treeVariables_step8;20',
#  'weightedEvents;1']

# %%
data = data[key]

# %%
data.keys()
# Out:
# ['top_pt',
#  'top_phi',
#  'top_rapidity',
#  'top_arapidity',
#  'top_eta',
#  'top_mass',
#  'top_boosted_theta',
#  'top_boosted_eta',
#  'top_theta_v2',
#  'tbar_pt',
#  'tbar_phi',
#  'tbar_rapidity',
#  'tbar_arapidity',
#  'tbar_eta',
#  'tbar_mass',
#  'tbar_boosted_theta',
#  'tbar_boosted_eta',
#  'l_pt',
#  'lbar_pt',
#  'e_pt',
#  'ebar_pt',
#  'mu_pt',
#  'mubar_pt',
#  'b_pt',
#  'bbar_pt',
#  'nu_pt',
#  'nubar_pt',
#  'l_eta',
#  'lbar_eta',
#  'e_eta',
#  'ebar_eta',
#  'mu_eta',
#  'mubar_eta',
#  'b_eta',
#  'bbar_eta',
#  'nu_eta',
#  'nubar_eta',
#  'l_phi',
#  'lbar_phi',
#  'e_phi',
#  'ebar_phi',
#  'mu_phi',
#  'mubar_phi',
#  'b_phi',
#  'bbar_phi',
#  'nu_phi',
#  'nubar_phi',
#  'l_mass',
#  'lbar_mass',
#  'e_mass',
#  'ebar_mass',
#  'mu_mass',
#  'mubar_mass',
#  'b_mass',
#  'bbar_mass',
#  'nu_mass',
#  'nubar_mass',
#  'met_pt',
#  'ttbar_pt',
#  'ttbar_phi',
#  'ttbar_rapidity',
#  'ttbar_arapidity',
#  'ttbar_delta_phi',
#  'ttbar_delta_eta',
#  'ttbar_delta_rapidity',
#  'ttbar_mass',
#  'ttbar_eta',
#  'ttbar_boosted_pt',
#  'wplus_pt',
#  'wplus_eta',
#  'wplus_phi',
#  'wplus_mass',
#  'wminus_pt',
#  'wminus_eta',
#  'wminus_phi',
#  'wminus_mass',
#  'llbar_pt',
#  'llbar_phi',
#  'llbar_rapidity',
#  'llbar_arapidity',
#  'llbar_delta_phi',
#  'llbar_delta_eta',
#  'llbar_delta_rapidity',
#  'llbar_mass',
#  'bbbar_pt',
#  'bbbar_phi',
#  'bbbar_rapidity',
#  'bbbar_arapidity',
#  'bbbar_delta_phi',
#  'bbbar_delta_eta',
#  'bbbar_delta_rapidity',
#  'llbar_mass',
#  'nunubar_pt',
#  'nunubar_phi',
#  'nunubar_rapidity',
#  'nunubar_arapidity',
#  'nunubar_delta_phi',
#  'nunubar_delta_eta',
#  'nunubar_delta_rapidity',
#  'nunubar_mass',
#  'MT2',
#  'all_mass',
#  'r_mass',
#  'jet_multiplicity',
#  'bjet_multiplicity',
#  'x1',
#  'x2',
#  'production_mode',
#  'b1k',
#  'b2k',
#  'b1j',
#  'b2j',
#  'b1r',
#  'b2r',
#  'b1q',
#  'b2q',
#  'b1n',
#  'b2n',
#  'b_Pkk',
#  'b_Mkk',
#  'b_Pjj',
#  'b_Mjj',
#  'b_Prr',
#  'b_Mrr',
#  'b_Pqq',
#  'b_Mqq',
#  'b_Pnn',
#  'b_Mnn',
#  'c_kk',
#  'c_rr',
#  'c_nn',
#  'c_rk',
#  'c_kr',
#  'c_nr',
#  'c_rn',
#  'c_nk',
#  'c_kn',
#  'c_Prk',
#  'c_Mrk',
#  'c_Pnr',
#  'c_Mnr',
#  'c_Pnk',
#  'c_Mnk',
#  'll_cHel',
#  'll_cLab',
#  'll_kNorm',
#  'll_rNorm',
#  'gen_top_pt',
#  'gen_top_phi',
#  'gen_top_rapidity',
#  'gen_top_arapidity',
#  'gen_tbar_pt',
#  'gen_tbar_phi',
#  'gen_tbar_rapidity',
#  'gen_tbar_arapidity',
#  'gen_l_pt',
#  'gen_lbar_pt',
#  'gen_e_pt',
#  'gen_ebar_pt',
#  'gen_mu_pt',
#  'gen_mubar_pt',
#  'gen_b_pt',
#  'gen_bbar_pt',
#  'gen_nu_pt',
#  'gen_nubar_pt',
#  'gen_l_eta',
#  'gen_lbar_eta',
#  'gen_e_eta',
#  'gen_ebar_eta',
#  'gen_mu_eta',
#  'gen_mubar_eta',
#  'gen_b_eta',
#  'gen_bbar_eta',
#  'gen_nu_eta',
#  'gen_nubar_eta',
#  'gen_l_phi',
#  'gen_lbar_phi',
#  'gen_e_phi',
#  'gen_ebar_phi',
#  'gen_mu_phi',
#  'gen_mubar_phi',
#  'gen_b_phi',
#  'gen_bbar_phi',
#  'gen_nu_phi',
#  'gen_nubar_phi',
#  'gen_ttbar_pt',
#  'gen_ttbar_phi',
#  'gen_ttbar_rapidity',
#  'gen_ttbar_arapidity',
#  'gen_ttbar_delta_phi',
#  'gen_ttbar_delta_eta',
#  'gen_ttbar_delta_rapidity',
#  'gen_ttbar_mass',
#  'gen_llbar_pt',
#  'gen_llbar_phi',
#  'gen_llbar_rapidity',
#  'gen_llbar_arapidity',
#  'gen_llbar_delta_phi',
#  'gen_llbar_delta_eta',
#  'gen_llbar_delta_rapidity',
#  'gen_llbar_mass',
#  'gen_bbbar_pt',
#  'gen_bbbar_phi',
#  'gen_bbbar_rapidity',
#  'gen_bbbar_arapidity',
#  'gen_bbbar_delta_phi',
#  'gen_bbbar_delta_eta',
#  'gen_bbbar_delta_rapidity',
#  'gen_bbbar_mass',
#  'gen_nunubar_pt',
#  'gen_nunubar_phi',
#  'gen_nunubar_rapidity',
#  'gen_nunubar_arapidity',
#  'gen_nunubar_delta_phi',
#  'gen_nunubar_delta_eta',
#  'gen_nunubar_delta_rapidity',
#  'gen_nunubar_mass',
#  'gen_MT2',
#  'gen_all_mass',
#  'gen_r_mass',
#  'gen_jet_multiplicity',
#  'gen_x1',
#  'gen_x2',
#  'gen_theta',
#  'gen_b1k',
#  'gen_b2k',
#  'gen_b1j',
#  'gen_b2j',
#  'gen_b1r',
#  'gen_b2r',
#  'gen_b1q',
#  'gen_b2q',
#  'gen_b1n',
#  'gen_b2n',
#  'gen_b_Pkk',
#  'gen_b_Mkk',
#  'gen_b_Pjj',
#  'gen_b_Mjj',
#  'gen_b_Prr',
#  'gen_b_Mrr',
#  'gen_b_Pqq',
#  'gen_b_Mqq',
#  'gen_b_Pnn',
#  'gen_b_Mnn',
#  'gen_c_kk',
#  'gen_c_rr',
#  'gen_c_nn',
#  'gen_c_rk',
#  'gen_c_kr',
#  'gen_c_nr',
#  'gen_c_rn',
#  'gen_c_nk',
#  'gen_c_kn',
#  'gen_c_Prk',
#  'gen_c_Mrk',
#  'gen_c_Pnr',
#  'gen_c_Mnr',
#  'gen_c_Pnk',
#  'gen_c_Mnk',
#  'gen_ll_cHel',
#  'gen_ll_cLab',
#  'gen_ll_kNorm',
#  'gen_ll_rNorm',
#  'entry',
#  'isTopGen',
#  'isKinReco',
#  'eventWeight',
#  'trueLevelWeight']

# %%
df = pd.DataFrame()

# %%
df["l_eta"] = data['/l_eta'].array(library="np")
df["lbar_eta"] = data['/lbar_eta'].array(library="np")

df["l_phi"] = data['/l_phi'].array(library="np")
df["lbar_phi"] = data['/lbar_phi'].array(library="np")

df["l_pt"] = data["/l_pt"]. array(library="np")
df["lbar_pt"] = data["/lbar_pt"]. array(library="np")

df["l_mass"] = data["/l_mass"]. array(library="np")
df["lbar_mass"] = data["lbar_mass"]. array(library="np")

df["b_eta"] = data['/b_eta'].array(library="np")
df["bbar_eta"] = data['/bbar_eta'].array(library="np")

df["b_phi"] = data['/b_phi'].array(library="np")
df["bbar_phi"] = data['/bbar_phi'].array(library="np")

df["b_pt"] = data["/b_pt"]. array(library="np")
df["bbar_pt"] = data["/bbar_pt"]. array(library="np")

df["b_mass"] = data["/b_mass"]. array(library="np")
df["bbar_mass"] = data["bbar_mass"]. array(library="np")

df["ttbar_mass"] = data["/ttbar_mass"].array(library="np")

# %%
df["production_mode"] = data["/production_mode"].array(library = "np")
df["eventWeight"] = data["/eventWeight"].array(library = "np")

# %%
df
# Out:
#            l_eta  lbar_eta     l_phi  lbar_phi        l_pt    lbar_pt  \
# 0      -0.418433 -1.052752 -2.833142  1.046932   38.249668  77.186279
# 1       0.441714  0.766434  1.654807  0.330907   61.005005  46.890030
# 2      -0.865866  1.428172  0.777443  2.173660   35.076176  35.803974
# 3      -0.689974  0.559789 -1.873679 -1.979171   45.656155  27.708010
# 4      -0.968490 -1.055607  2.875477 -0.203843   50.032631  64.268913
# ...          ...       ...       ...       ...         ...        ...
# 814619 -1.162241 -1.198242  1.685994  3.138009   28.753149  47.246441
# 814620 -0.715591 -2.284375  2.781940 -0.407584   82.431305  31.893370
# 814621  1.740124 -0.224671  2.429759 -0.769177   80.669838  90.743553
# 814622 -0.130503  0.403787 -1.643343  2.686914  120.145020  73.975929
# 814623 -0.956351 -0.840376  2.221087 -0.040523   26.943182  42.179310
#
#           l_mass  lbar_mass     b_eta  bbar_eta     b_phi  bbar_phi  \
# 0      -0.009397   0.039436 -0.614827 -0.820250  2.933657 -1.405498
# 1      -0.024074   0.017834  0.614596  0.103369  2.838979 -2.446813
# 2       0.024741  -0.030859  0.061632 -1.056999  2.019093 -2.945541
# 3      -0.014371  -0.013788 -0.509759 -0.534511 -2.956155  1.209700
# 4       0.025838   0.031779  0.724862 -1.819934  0.260258  1.135078
# ...          ...        ...       ...       ...       ...       ...
# 814619  0.019022   0.017370 -1.723179 -1.734083 -1.734641  0.997673
# 814620  0.014681   0.055458 -1.439634 -0.577249  0.399481 -2.221793
# 814621 -0.033933   0.020309  0.459560  1.050448 -0.526567  1.679222
# 814622 -0.043836  -0.027999 -0.858372  0.661345  2.069742 -2.345472
# 814623 -0.012715  -0.019373 -1.031379 -1.798241  0.451868  2.091135
#
#               b_pt     bbar_pt     b_mass  bbar_mass  ttbar_mass  \
# 0        43.164726   61.223160   7.076938   7.735636  395.892334
# 1        58.718460   57.919064   9.041662   8.061164  357.865204
# 2        43.454281   78.188980  10.787407  10.321366  568.250061
# 3        63.876171   70.141838  11.685390  10.414097  373.534393
# 4        37.103329   51.873825   8.260054   7.048822  428.166321
# ...            ...         ...        ...        ...         ...
# 814619   81.831055  150.701614  15.274540  13.668813  468.926697
# 814620   45.463120  119.378471   6.430285  10.532022  635.448181
# 814621  157.176483   92.111130  13.466886  12.534403  712.447571
# 814622   48.212143  100.290535   7.868330  15.297538  446.921509
# 814623   63.471409   71.272690   9.130685  11.300347  664.445312
#
#         production_mode  eventWeight
# 0                   0.0    66.410027
# 1                   1.0     7.390667
# 2                   0.0    77.069023
# 3                   0.0    76.395515
# 4                   0.0    71.350548
# ...                 ...          ...
# 814619              2.0    53.111862
# 814620              0.0    68.907211
# 814621              1.0    71.193085
# 814622              2.0    73.394135
# 814623              0.0    64.527901
#
# [814624 rows x 19 columns]

# %%
# file path
path  = "/depot/cms/top/mcnama20/TopSpinCorr-Run2-Entanglement/CMSSW_10_2_22/src/TopAnalysis/Configuration/analysis/diLeptonic/three_files/Nominal"

# %%
# df.to_root(path + channel + '_modified_root_1_lorentzvectors_mttbar_mass.root', key = key)
