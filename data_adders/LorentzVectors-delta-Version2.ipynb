# %%
import uproot
import matplotlib
import ipykernel
import numpy as np
import scipy
import torch
import pandas as pd
import sklearn
import uproot as uproot
import root_pandas

# %%
depo_dir = '/depot/cms/top/mcnama20/TopSpinCorr-Run2-Entanglement/CMSSW_10_2_22/src/TopAnalysis/Configuration/analysis/diLeptonic/spinCorrInput_gendata_all/Nominal'
channel = "/mumu"  # can also be "/ee", /emu" and "/mumu"

file = channel + "_ttbarsignalplustau_fromDilepton_TuneCP5.root"

gen = True

# %%
key = ""
if channel == "/ee":
    key = "ttBar_treeVariables_step8;21"
elif channel == "/emu":
    key = "ttBar_treeVariables_step8;88"
elif channel == "/mumu":
    key = "ttBar_treeVariables_step8;40"
else:
    print("Error!!!!")

prepend = ""
if gen:
    prepend = "gen_"

# %%
data = uproot.open(depo_dir + channel + file, key = key)

# %%
data.keys()
# Out:
# ['ttBar_treeVariables_step0;106',
#  'ttBar_treeVariables_step0;105',
#  'ttBar_treeVariables_step1;95',
#  'ttBar_treeVariables_step1;94',
#  'ttBar_treeVariables_step3;84',
#  'ttBar_treeVariables_step3;83',
#  'ttBar_treeVariables_step4;66',
#  'ttBar_treeVariables_step4;65',
#  'ttBar_treeVariables_step5;57',
#  'ttBar_treeVariables_step5;56',
#  'ttBar_treeVariables_step6;48',
#  'ttBar_treeVariables_step6;47',
#  'ttBar_treeVariables_step2;48',
#  'ttBar_treeVariables_step2;47',
#  'ttBar_treeVariables_step7;46',
#  'ttBar_treeVariables_step7;45',
#  'ttBar_treeVariables_step8;40',
#  'ttBar_treeVariables_step8;39',
#  'weightedEvents;1']

# %%
data = data[key]

# %%
data.keys()
# Out:
# ['top_pt',
#  'top_phi',
#  'top_rapidity',
#  'top_arapidity',
#  'top_eta',
#  'top_mass',
#  'top_boosted_theta',
#  'top_boosted_eta',
#  'top_theta_v2',
#  'tbar_pt',
#  'tbar_phi',
#  'tbar_rapidity',
#  'tbar_arapidity',
#  'tbar_eta',
#  'tbar_mass',
#  'tbar_boosted_theta',
#  'tbar_boosted_eta',
#  'l_pt',
#  'lbar_pt',
#  'e_pt',
#  'ebar_pt',
#  'mu_pt',
#  'mubar_pt',
#  'b_pt',
#  'bbar_pt',
#  'nu_pt',
#  'nubar_pt',
#  'l_eta',
#  'lbar_eta',
#  'e_eta',
#  'ebar_eta',
#  'mu_eta',
#  'mubar_eta',
#  'b_eta',
#  'bbar_eta',
#  'nu_eta',
#  'nubar_eta',
#  'l_phi',
#  'lbar_phi',
#  'e_phi',
#  'ebar_phi',
#  'mu_phi',
#  'mubar_phi',
#  'b_phi',
#  'bbar_phi',
#  'nu_phi',
#  'nubar_phi',
#  'l_mass',
#  'lbar_mass',
#  'e_mass',
#  'ebar_mass',
#  'mu_mass',
#  'mubar_mass',
#  'b_mass',
#  'bbar_mass',
#  'nu_mass',
#  'nubar_mass',
#  'met_pt',
#  'ttbar_pt',
#  'ttbar_phi',
#  'ttbar_rapidity',
#  'ttbar_arapidity',
#  'ttbar_delta_phi',
#  'ttbar_delta_eta',
#  'ttbar_delta_rapidity',
#  'ttbar_mass',
#  'ttbar_eta',
#  'ttbar_boosted_pt',
#  'wplus_pt',
#  'wplus_eta',
#  'wplus_phi',
#  'wplus_mass',
#  'wminus_pt',
#  'wminus_eta',
#  'wminus_phi',
#  'wminus_mass',
#  'llbar_pt',
#  'llbar_phi',
#  'llbar_rapidity',
#  'llbar_arapidity',
#  'llbar_delta_phi',
#  'llbar_delta_eta',
#  'llbar_delta_rapidity',
#  'llbar_mass',
#  'bbbar_pt',
#  'bbbar_phi',
#  'bbbar_rapidity',
#  'bbbar_arapidity',
#  'bbbar_delta_phi',
#  'bbbar_delta_eta',
#  'bbbar_delta_rapidity',
#  'llbar_mass',
#  'nunubar_pt',
#  'nunubar_phi',
#  'nunubar_rapidity',
#  'nunubar_arapidity',
#  'nunubar_delta_phi',
#  'nunubar_delta_eta',
#  'nunubar_delta_rapidity',
#  'nunubar_mass',
#  'MT2',
#  'all_mass',
#  'r_mass',
#  'jet_multiplicity',
#  'bjet_multiplicity',
#  'x1',
#  'x2',
#  'production_mode',
#  'b1k',
#  'b2k',
#  'b1j',
#  'b2j',
#  'b1r',
#  'b2r',
#  'b1q',
#  'b2q',
#  'b1n',
#  'b2n',
#  'b_Pkk',
#  'b_Mkk',
#  'b_Pjj',
#  'b_Mjj',
#  'b_Prr',
#  'b_Mrr',
#  'b_Pqq',
#  'b_Mqq',
#  'b_Pnn',
#  'b_Mnn',
#  'c_kk',
#  'c_rr',
#  'c_nn',
#  'c_rk',
#  'c_kr',
#  'c_nr',
#  'c_rn',
#  'c_nk',
#  'c_kn',
#  'c_Prk',
#  'c_Mrk',
#  'c_Pnr',
#  'c_Mnr',
#  'c_Pnk',
#  'c_Mnk',
#  'll_cHel',
#  'll_cLab',
#  'll_kNorm',
#  'll_rNorm',
#  'gen_top_pt',
#  'gen_top_phi',
#  'gen_top_eta',
#  'gen_top_rapidity',
#  'gen_top_arapidity',
#  'gen_tbar_pt',
#  'gen_tbar_phi',
#  'gen_tbar_eta',
#  'gen_tbar_rapidity',
#  'gen_tbar_arapidity',
#  'gen_l_pt',
#  'gen_lbar_pt',
#  'gen_e_pt',
#  'gen_ebar_pt',
#  'gen_mu_pt',
#  'gen_mubar_pt',
#  'gen_b_pt',
#  'gen_bbar_pt',
#  'gen_nu_pt',
#  'gen_nubar_pt',
#  'gen_l_eta',
#  'gen_lbar_eta',
#  'gen_e_eta',
#  'gen_ebar_eta',
#  'gen_mu_eta',
#  'gen_mubar_eta',
#  'gen_b_eta',
#  'gen_bbar_eta',
#  'gen_nu_eta',
#  'gen_nubar_eta',
#  'gen_l_phi',
#  'gen_lbar_phi',
#  'gen_e_phi',
#  'gen_ebar_phi',
#  'gen_mu_phi',
#  'gen_mubar_phi',
#  'gen_b_phi',
#  'gen_bbar_phi',
#  'gen_nu_phi',
#  'gen_nubar_phi',
#  'gen_l_mass',
#  'gen_lbar_mass',
#  'gen_e_mass',
#  'gen_ebar_mass',
#  'gen_mu_mass',
#  'gen_mubar_mass',
#  'gen_b_mass',
#  'gen_bbar_mass',
#  'gen_nu_mass',
#  'gen_nubar_mass',
#  'gen_wplus_pt',
#  'gen_wplus_eta',
#  'gen_wplus_phi',
#  'gen_wplus_mass',
#  'gen_wminus_pt',
#  'gen_wminus_eta',
#  'gen_wminus_phi',
#  'gen_wminus_mass',
#  'gen_ttbar_pt',
#  'gen_ttbar_phi',
#  'gen_ttbar_rapidity',
#  'gen_ttbar_arapidity',
#  'gen_ttbar_delta_phi',
#  'gen_ttbar_delta_eta',
#  'gen_ttbar_delta_rapidity',
#  'gen_ttbar_mass',
#  'gen_llbar_pt',
#  'gen_llbar_phi',
#  'gen_llbar_rapidity',
#  'gen_llbar_arapidity',
#  'gen_llbar_delta_phi',
#  'gen_llbar_delta_eta',
#  'gen_llbar_delta_rapidity',
#  'gen_llbar_mass',
#  'gen_bbbar_pt',
#  'gen_bbbar_phi',
#  'gen_bbbar_rapidity',
#  'gen_bbbar_arapidity',
#  'gen_bbbar_delta_phi',
#  'gen_bbbar_delta_eta',
#  'gen_bbbar_delta_rapidity',
#  'gen_bbbar_mass',
#  'gen_nunubar_pt',
#  'gen_nunubar_phi',
#  'gen_nunubar_rapidity',
#  'gen_nunubar_arapidity',
#  'gen_nunubar_delta_phi',
#  'gen_nunubar_delta_eta',
#  'gen_nunubar_delta_rapidity',
#  'gen_nunubar_mass',
#  'gen_MT2',
#  'gen_all_mass',
#  'gen_r_mass',
#  'gen_jet_multiplicity',
#  'gen_x1',
#  'gen_x2',
#  'gen_theta',
#  'gen_b1k',
#  'gen_b2k',
#  'gen_b1j',
#  'gen_b2j',
#  'gen_b1r',
#  'gen_b2r',
#  'gen_b1q',
#  'gen_b2q',
#  'gen_b1n',
#  'gen_b2n',
#  'gen_b_Pkk',
#  'gen_b_Mkk',
#  'gen_b_Pjj',
#  'gen_b_Mjj',
#  'gen_b_Prr',
#  'gen_b_Mrr',
#  'gen_b_Pqq',
#  'gen_b_Mqq',
#  'gen_b_Pnn',
#  'gen_b_Mnn',
#  'gen_c_kk',
#  'gen_c_rr',
#  'gen_c_nn',
#  'gen_c_rk',
#  'gen_c_kr',
#  'gen_c_nr',
#  'gen_c_rn',
#  'gen_c_nk',
#  'gen_c_kn',
#  'gen_c_Prk',
#  'gen_c_Mrk',
#  'gen_c_Pnr',
#  'gen_c_Mnr',
#  'gen_c_Pnk',
#  'gen_c_Mnk',
#  'gen_ll_cHel',
#  'gen_ll_cLab',
#  'gen_ll_kNorm',
#  'gen_ll_rNorm',
#  'entry',
#  'isTopGen',
#  'isKinReco',
#  'eventWeight',
#  'trueLevelWeight']

# %%
df = pd.DataFrame()

# %%
df[prepend + "l_eta"] = data['/' + prepend + 'l_eta'].array(library="np")
df[prepend + "lbar_eta"] = data['/' + prepend + 'lbar_eta'].array(library="np")

df[prepend + "l_phi"] = data['/' + prepend + 'l_phi'].array(library="np")
df[prepend +  "lbar_phi"] = data['/' + prepend + 'lbar_phi'].array(library="np")

df[prepend + "l_pt"] = data['/' + prepend + 'l_pt']. array(library="np")
df[prepend + "lbar_pt"] = data['/' + prepend + 'lbar_pt']. array(library="np")

df[prepend + "l_mass"] = data['/' + prepend + 'l_mass']. array(library="np")
df[prepend + "lbar_mass"] = data['/' + prepend + 'lbar_mass']. array(library="np")

df[prepend + "b_eta"] = data['/' + prepend + 'b_eta'].array(library="np")
df[prepend + "bbar_eta"] = data['/' + prepend + 'bbar_eta'].array(library="np")

df[prepend + "b_phi"] = data['/' + prepend + 'b_phi'].array(library="np")
df[prepend + "bbar_phi"] = data['/' + prepend + 'bbar_phi'].array(library="np")

df[prepend + "b_pt"] = data['/' + prepend + 'b_pt']. array(library="np")
df[prepend + "bbar_pt"] = data['/' + prepend + 'bbar_pt']. array(library="np")

df[prepend + "b_mass"] = data['/' + prepend + 'b_mass']. array(library="np")
df[prepend + "bbar_mass"] = data['/' + prepend + 'bbar_mass']. array(library="np")

# %%
df[prepend + "llbar_delta_eta"] =  data['/' + prepend + 'llbar_delta_eta'].array(library="np")
df[prepend + "bbbar_delta_eta"] =  data['/' + prepend + 'bbbar_delta_eta'].array(library="np")
df[prepend + "lbbar_delta_eta"] =  data['/' + prepend + 'l_eta'].array(library="np") -  data['/bbar_eta'].array(library="np")
df[prepend + "blbar_delta_eta"] =  data['/' + prepend + 'b_eta'].array(library="np") -  data['/lbar_eta'].array(library="np")
df[prepend + "lb_delta_eta"] =  (data['/' + prepend + 'l_eta'].array(library="np") -  data['/b_eta'].array(library="np"))%np.pi
df[prepend + "bbarlbar_delta_eta"] =  (data['/' + prepend + 'bbar_eta'].array(library="np") -  data['/lbar_eta'].array(library="np"))%np.pi

# %%
df[prepend + "llbar_delta_phi"] =  data['/' + prepend + 'llbar_delta_phi'].array(library="np")
df[prepend + "bbbar_delta_phi"] =  data['/' + prepend + 'bbbar_delta_phi'].array(library="np")
df[prepend + "lbbar_delta_phi"] =  (data['/' + prepend + 'l_phi'].array(library="np") -  data['/bbar_phi'].array(library="np"))%np.pi
df[prepend + "blbar_delta_phi"] =  (data['/' + prepend + 'b_phi'].array(library="np") -  data['/lbar_phi'].array(library="np"))%np.pi
df[prepend + "lb_delta_phi"] =  (data['/' + prepend + 'l_phi'].array(library="np") -  data['/b_phi'].array(library="np"))%np.pi
df[prepend + "bbarlbar_delta_phi"] =  (data['/' + prepend + 'bbar_phi'].array(library="np") -  data['/lbar_phi'].array(library="np"))%np.pi

# %%
df["production_mode"] = data["/production_mode"].array(library = "np")
if not gen:
    df["eventWeight"] = data["/eventWeight"].array(library = "np")
else:
    df["eventWeight"] = data["/trueLevelWeight"].array(library = "np")

# %%
df
# Out:
#          gen_l_eta  gen_lbar_eta  gen_l_phi  gen_lbar_phi   gen_l_pt  \
# 0        -0.147476      0.278772  -2.397985     -0.719668  67.724655
# 1        -1.252163     -1.957572  -0.798366      3.041105  56.699417
# 2         1.236017      0.067538   0.967749     -3.135678  23.626526
# 3        -0.526922     -0.177490  -1.815812      0.931568  65.365326
# 4        -0.651479     -1.437795  -2.446484      1.278299  72.354576
# ...            ...           ...        ...           ...        ...
# 1587253   0.805721      1.870169  -2.626273      1.192731  34.002316
# 1587254  -1.413684     -0.557693   0.891357      1.482972  34.690063
# 1587255   2.013264     -0.271581   2.915999      0.301939  68.283501
# 1587256   1.106780      1.813023  -0.103317     -1.761943  20.615274
# 1587257  -1.345205      0.932846  -3.094144     -2.548032  49.464306
#
#          gen_lbar_pt  gen_l_mass  gen_lbar_mass  gen_b_eta  gen_bbar_eta  ...  \
# 0          22.468784    0.110587       0.105626   0.695835      0.367011  ...
# 1          57.098652    0.101206       0.117998  -0.928433     -0.897128  ...
# 2         119.185921    0.105176       0.100686  -0.505498     -0.746633  ...
# 3          72.006912    0.104431       0.105312  -1.836752     -1.180908  ...
# 4          74.199303    0.100757       0.068741  -0.276644      0.295384  ...
# ...              ...         ...            ...        ...           ...  ...
# 1587253    23.446066    0.107725       0.108838   1.462547     -0.264192  ...
# 1587254    62.189056    0.105367       0.101112  -1.257251     -1.744442  ...
# 1587255    43.307529    0.129752       0.106969   0.464678      1.587710  ...
# 1587256    49.608032    0.106863       0.122016   0.858888     -0.677877  ...
# 1587257    34.465343    0.104515       0.103895   1.222001     -0.790278  ...
#
#          gen_lb_delta_eta  gen_bbarlbar_delta_eta  gen_llbar_delta_phi  \
# 0                2.608359                0.141600             1.678317
# 1                2.847174                1.060578             2.443714
# 2                1.740991                2.327384             2.179758
# 3                1.278073                2.138270             2.747380
# 4                2.055225                1.732967             2.558403
# ...                   ...                     ...                  ...
# 1587253          2.471850                1.006898             2.464181
# 1587254          0.346512                1.956646             0.591615
# 1587255          1.547164                1.859661             2.614060
# 1587256          0.229837                0.650648             1.658626
# 1587257          3.072540                1.418790             0.546112
#
#          gen_bbbar_delta_phi  gen_lbbar_delta_phi  gen_blbar_delta_phi  \
# 0                   3.089992             1.799575             2.854590
# 1                   2.451371             0.445368             2.681962
# 2                   2.354763             0.913057             2.378661
# 3                   3.024762             2.036997             1.401014
# 4                   2.795877             0.371654             2.574558
# ...                      ...                  ...                  ...
# 1587253             0.491410             1.624391             1.149223
# 1587254             1.463319             2.791891             3.100078
# 1587255             1.698194             2.956215             1.218436
# 1587256             2.892513             2.725219             2.314178
# 1587257             0.634632             2.809444             2.056754
#
#          gen_lb_delta_phi  gen_bbarlbar_delta_phi  production_mode  \
# 0                1.768506                2.906191              0.0
# 1                2.907582                1.991741              1.0
# 2                1.726535                0.023899              0.0
# 3                2.152623                1.517845              0.0
# 4                3.037289                2.228842              2.0
# ...                   ...                     ...              ...
# 1587253          1.321526                1.640634              0.0
# 1587254          1.159616                1.421805              2.0
# 1587255          1.414338                2.661834              0.0
# 1587256          2.504741                2.065099              0.0
# 1587257          2.357891                2.691386              0.0
#
#          eventWeight
# 0          42.955936
# 1          77.017059
# 2          84.624817
# 3          80.623962
# 4          73.820694
# ...              ...
# 1587253    74.526512
# 1587254    77.210739
# 1587255    75.042679
# 1587256    84.624817
# 1587257    73.484268
#
# [1587258 rows x 30 columns]

# %%
# file path
path  = "/depot/cms/top/mcnama20/TopSpinCorr-Run2-Entanglement/CMSSW_10_2_22/src/TopAnalysis/Configuration/analysis/diLeptonic/three_files/Nominal"

# %%
# df.to_root(path + channel + '_modified_root_1_lorentzvectorsdelta_version2.root', key = key)

# %%
# df.to_root(path + channel + '_modified_root_1_lorentzvectorsdelta_gen.root', key = key)
